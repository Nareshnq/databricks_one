# %%
# this is a demo notebook I am creating just to test the connection and varify the changes

# %%
# this is the second cell I am writing to see another commit updates , after that I will push it to remote repo
